# %%
pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in c:\users\ccl37\appdata\local\programs\python\python310\lib\site-packages (8.0.29)
# Requirement already satisfied: protobuf>=3.0.0 in c:\users\ccl37\appdata\local\programs\python\python310\lib\site-packages (from mysql-connector-python) (4.21.3)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ip (c:\users\ccl37\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\ccl37\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\ccl37\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\ccl37\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\ccl37\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\ccl37\appdata\local\programs\python\python310\lib\site-packages)
#
# [notice] A new release of pip available: 22.2.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import mysql.connector

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password=""
)

print(mydb)
# Out:
# <mysql.connector.connection_cext.CMySQLConnection object at 0x000002379A077730>

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password=""
)

mycursor = mydb.cursor()

mycursor.execute("SHOW DATABASES")

for x in mycursor:
  print(x)
# Out:
# ('blogdb',)
# ('docdb',)
# ('information_schema',)
# ('internalblog',)
# ('mysql',)
# ('performance_schema',)
# ('phpmyadmin',)
# ('retailshop',)
# ('test',)

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password=""
)

mycursor = mydb.cursor()

mycursor.execute("SHOW DATABASES")

for x in mycursor:
  print(x)
# Out:
# ('blogdb',)
# ('docdb',)
# ('information_schema',)
# ('internalblog',)
# ('mysql',)
# ('performance_schema',)
# ('phpmyadmin',)
# ('pythondatabase',)
# ('retailshop',)
# ('test',)

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password=""
)

mycursor = mydb.cursor()

mycursor.execute("CREATE DATABASE pythondatabase")

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="pythondatabase"
)

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="pythondatabase"
)

mycursor = mydb.cursor()

mycursor.execute("CREATE TABLE customers (name VARCHAR(255), address VARCHAR(255))")

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="pythondatabase"
)

mycursor = mydb.cursor()

mycursor.execute("SHOW TABLES")

for x in mycursor:
  print(x)
# Out:
# ('customers',)

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="pythondatabase"
)

mycursor = mydb.cursor()

mycursor.execute("ALTER TABLE customers ADD COLUMN id INT AUTO_INCREMENT PRIMARY KEY")

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password=""
)

mycursor = mydb.cursor()

mycursor.execute("CREATE DATABASE StudentERP")

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="pythondatabase"
)

mycursor = mydb.cursor()

mycursor.execute("CREATE TABLE student (name VARCHAR(255), address VARCHAR(255))")

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="StudentERP"
)

mycursor = mydb.cursor()

mycursor.execute("CREATE TABLE student (name VARCHAR(255), address VARCHAR(255))")

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="StudentERP"
)

mycursor = mydb.cursor()

sql = "INSERT INTO student (name, address) VALUES (%s, %s)"
val = [
  ('Peter', 'bristol 4'),
  
  
  ('john', 'Sideway 1633')
]

mycursor.executemany(sql, val)

mydb.commit()

print(mycursor.rowcount, "was inserted.")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File c:\Users\CCL37\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py:535, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     534         query = query.encode('utf-8')
# --> 535     self._cmysql.query(query,
#     536                        raw=raw, buffered=buffered,
#     537                        raw_as_string=raw_as_string,
#     538                        query_attrs=self._query_attrs)
#     539 except MySQLInterfaceError as exc:
#
# MySQLInterfaceError: Table 'studenterp.student' doesn't exist
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[14], line 20
#      12 sql = "INSERT INTO student (name, address) VALUES (%s, %s)"
#      13 val = [
#      14   ('Peter', 'bristol 4'),
#      15
#      16
#      17   ('john', 'Sideway 1633')
#      18 ]
# ---> 20 mycursor.executemany(sql, val)
#      22 mydb.commit()
#      24 print(mycursor.rowcount, "was inserted.")
#
# File c:\Users\CCL37\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py:358, in CMySQLCursor.executemany(self, operation, seq_params)
#     356     if stmt is not None:
#     357         self._executed = stmt
# --> 358         return self.execute(stmt)
#     360 rowcnt = 0
#     361 try:
#
# File c:\Users\CCL37\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py:269, in CMySQLCursor.execute(self, operation, params, multi)
#     265             raise errors.ProgrammingError(
#     266                 "Not all parameters were used in the SQL statement")
#     268 try:
# --> 269     result = self._cnx.cmd_query(stmt, raw=self._raw,
#     270                                  buffered=self._buffered,
#     271                                  raw_as_string=self._raw_as_string)
#     272 except MySQLInterfaceError as exc:
#     273     raise errors.get_mysql_exception(msg=exc.msg, errno=exc.errno,
#     274                                      sqlstate=exc.sqlstate)
#
# File c:\Users\CCL37\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py:540, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     535     self._cmysql.query(query,
#     536                        raw=raw, buffered=buffered,
#     537                        raw_as_string=raw_as_string,
#     538                        query_attrs=self._query_attrs)
#     539 except MySQLInterfaceError as exc:
# --> 540     raise errors.get_mysql_exception(exc.errno, msg=exc.msg,
#     541                                      sqlstate=exc.sqlstate)
#     542 except AttributeError:
#     543     if self._unix_socket:
#
# ProgrammingError: 1146 (42S02): Table 'studenterp.student' doesn't exist

# %%
mport mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="StudentERP"
)

mycursor = mydb.cursor()

sql = "INSERT INTO student (name, address) VALUES (%s, %s)"
val = [
  ('Peter', 'bristol 4'),
  
  
  ('john', 'Sideway 1633')
]

mycursor.executemany(sql, val)

mydb.commit()

print(mycursor.rowcount, "was inserted.")
# Out:
#   Cell In[17], line 1
#     mport mysql.connector
#           ^
# SyntaxError: invalid syntax

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="StudentERP"
)

mycursor = mydb.cursor()

sql = "INSERT INTO student (name, address) VALUES (%s, %s)"
val = ("John", "Highway 21")
mycursor.execute(sql, val)

mydb.commit()

print(mycursor.rowcount, "record inserted.")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File c:\Users\CCL37\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py:535, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     534         query = query.encode('utf-8')
# --> 535     self._cmysql.query(query,
#     536                        raw=raw, buffered=buffered,
#     537                        raw_as_string=raw_as_string,
#     538                        query_attrs=self._query_attrs)
#     539 except MySQLInterfaceError as exc:
#
# MySQLInterfaceError: Table 'studenterp.student' doesn't exist
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[15], line 14
#      12 sql = "INSERT INTO student (name, address) VALUES (%s, %s)"
#      13 val = ("John", "Highway 21")
# ---> 14 mycursor.execute(sql, val)
#      16 mydb.commit()
#      18 print(mycursor.rowcount, "record inserted.")
#
# File c:\Users\CCL37\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py:269, in CMySQLCursor.execute(self, operation, params, multi)
#     265             raise errors.ProgrammingError(
#     266                 "Not all parameters were used in the SQL statement")
#     268 try:
# --> 269     result = self._cnx.cmd_query(stmt, raw=self._raw,
#     270                                  buffered=self._buffered,
#     271                                  raw_as_string=self._raw_as_string)
#     272 except MySQLInterfaceError as exc:
#     273     raise errors.get_mysql_exception(msg=exc.msg, errno=exc.errno,
#     274                                      sqlstate=exc.sqlstate)
#
# File c:\Users\CCL37\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py:540, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     535     self._cmysql.query(query,
#     536                        raw=raw, buffered=buffered,
#     537                        raw_as_string=raw_as_string,
#     538                        query_attrs=self._query_attrs)
#     539 except MySQLInterfaceError as exc:
# --> 540     raise errors.get_mysql_exception(exc.errno, msg=exc.msg,
#     541                                      sqlstate=exc.sqlstate)
#     542 except AttributeError:
#     543     if self._unix_socket:
#
# ProgrammingError: 1146 (42S02): Table 'studenterp.student' doesn't exist

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="StudentERP"
)

mycursor = mydb.cursor()

sql = "INSERT INTO student (name, address) VALUES (%s, %s)"
val = ("John", "Highway 21")
mycursor.execute(sql, val)

mydb.commit()

print(mycursor.rowcount, "record inserted.")
# Out:
# 1 record inserted.

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="StudentERP"
)

mycursor = mydb.cursor()

sql = "INSERT INTO student (name, address) VALUES (%s, %s)"
val = ("peter", "bristol 21")
mycursor.execute(sql, val)

mydb.commit()

print(mycursor.rowcount, "record inserted.")
# Out:
# 1 record inserted.

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="StudentERP"
)

mycursor = mydb.cursor()

sql = "UPDATE student SET address = 'Canyon 123' WHERE address = 'bristol 21'"

mycursor.execute(sql)

mydb.commit()

print(mycursor.rowcount, "record(s) affected")
# Out:
# 1 record(s) affected

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="StudentERP"
)

mycursor = mydb.cursor()

sql = "DELETE FROM student WHERE address = 'Canyon 123'"

mycursor.execute(sql)

mydb.commit()

print(mycursor.rowcount, "record(s) deleted")
# Out:
# 1 record(s) deleted
